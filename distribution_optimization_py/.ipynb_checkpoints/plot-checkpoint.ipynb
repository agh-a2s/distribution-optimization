# %%
import pandas as pd

raw_df = pd.read_csv("cs_results_original.csv")
raw_df["fitness"] = raw_df["fitness_mean"].round(5).astype(str) + " ± " + raw_df["fitness_std"].round(5).astype(str)

df = raw_df[["problem_id", "solver", "fitness"]].pivot(
    index="problem_id",
    columns="solver",
    values=["fitness"],
)

df
# Out:
#                               fitness                                        \
# solver                     CSDESolver           CSSolver           GASolver
# problem_id
# atmosphere_data     0.61846 ± 0.19693  1.34906 ± 0.32489  0.03257 ± 0.01542
# chromatogram_time   0.07291 ± 0.03677  0.53544 ± 0.16051  0.00163 ± 0.00147
# iris_ica            0.02206 ± 0.01561   0.2186 ± 0.11467  0.00315 ± 0.00392
# mixture3            0.06877 ± 0.05948   0.2944 ± 0.10087  0.01495 ± 0.03663
# textbook_data       0.03591 ± 0.01241  0.21344 ± 0.09135  0.01995 ± 0.00495
# truck_driving_data  0.06608 ± 0.00854  0.32068 ± 0.13317  0.07357 ± 0.00189
#
#
# solver                  iLSHADESolver
# problem_id
# atmosphere_data             0.0 ± 0.0
# chromatogram_time           0.0 ± 0.0
# iris_ica                    0.0 ± 0.0
# mixture3            0.00414 ± 0.00026
# textbook_data           0.00947 ± 0.0
# truck_driving_data      0.05718 ± 0.0
